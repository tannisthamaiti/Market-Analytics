# %% [markdown]
# foreach (var wall in _walls)
# {
#     Debug.WriteLine($"Obstacle Position: {wall.X}, {wall.Y}");
# }
# <table align="left">
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/GoogleCloudPlatform/generative-ai/blob/main/gemini/use-cases/intro_multimodal_use_cases.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/colab-logo-32px.png" alt="Google Colaboratory logo"><br> Run in Colab
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https:%2F%2Fraw.githubusercontent.com%2FGoogleCloudPlatform%2Fgenerative-ai%2Fmain%2Fgemini%2Fuse-cases%2Fintro_multimodal_use_cases.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo"><br> Run in Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/GoogleCloudPlatform/generative-ai/main/gemini/use-cases/intro_multimodal_use_cases.ipynb">
#       <img src="https://lh3.googleusercontent.com/UiNooY4LUgW_oTvpsNhPpQzsstV5W8F7rYgxgGBD85cWJoLmrOzhVs_ksK_vgx40SHs7jCqkTkCk=e14-rj-sc0xffffff-h130-w32" alt="Vertex AI logo"><br> Open in Vertex AI Workbench
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/use-cases/intro_multimodal_use_cases.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/github-logo-32px.png" alt="GitHub logo"><br> View on GitHub
#     </a>
#   </td>
# </table>

# %% [markdown]
# | | |
# |-|-|
# |Author(s) | [Tannistha Maiti](https://github.com/tannisthamaiti) |

# %%
# !pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from moviepy) (1.26.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.1.31)

# %%
from moviepy.editor import VideoFileClip

def extract_audio(video_file_path, audio_file_path):
    """
    Extracts audio from a video file and saves it as an MP3 file.

    Args:
    video_file_path (str): The path to the video file.
    audio_file_path (str): The path where the audio file will be saved.
    """
    # Load the video file
    video = VideoFileClip(video_file_path)

    # Extract the audio
    audio = video.audio

    # Write the audio to a file
    audio.write_audiofile(audio_file_path, codec='mp3')

    # Close the video and audio to free up resources
    audio.close()
    video.close()

# Usage
video_file_path = '/content/podcast1.mp4'
audio_file_path = '/content/output_audio.mp3'
extract_audio(video_file_path, audio_file_path)
# Out:
# MoviePy - Writing audio in /content/output_audio.mp3
# MoviePy - Done.

# %%
from moviepy.editor import ImageClip, AudioFileClip, concatenate_videoclips

# Path to your image and audio files
image_path = '/content/LiveAI_podcast.png'
audio_path = '/content/output_audio.mp3'

# Load the audio file
audio_clip = AudioFileClip(audio_path)

# Create a video clip from the image
image_clip = ImageClip(image_path)

# Set the duration of the image clip to the duration of the audio clip
image_clip = image_clip.set_duration(audio_clip.duration)

# Set the audio of the image clip to be the audio clip
video_clip = image_clip.set_audio(audio_clip)

# Optionally, you can write the result to a file
output_path = '/content/output_video.mp4'
video_clip.write_videofile(output_path, codec='libx264', fps=24)

# Close the clips to free up resources
audio_clip.close()
video_clip.close()
# Out:
# Moviepy - Building video /content/output_video.mp4.
# MoviePy - Writing audio in output_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/output_video.mp4
# Moviepy - Done !
# Moviepy - video ready /content/output_video.mp4

# %% [markdown]
# ### Define helper functions

# %%
import sqlite3
import os
import pandas as pd
import base64
from google.cloud import storage
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting


# Initialize database connection and cursor
def initialize_db(db_name):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS videos (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        type TEXT NOT NULL,
        data BLOB DEFAULT NULL,
        metadata TEXT DEFAULT NULL,
        description TEXT DEFAULT NULL
    );
    """)
    conn.commit()
    return conn, cursor


# Save raw video data and transcription chunks
def save_video_and_transcription(conn, cursor, video_uri, video_data, metadata, transcription_chunks):
    try:
        # Save raw video data
        cursor.execute(
            """
            INSERT INTO videos (type, data, metadata, description)
            VALUES (?, ?, ?, ?)
            """,
            ("video/mp4", video_data, metadata, f"Raw video data for {video_uri}")
        )
        video_id = cursor.lastrowid  # Get ID of the last inserted video

        # Save transcription chunks
        for i, chunk in enumerate(transcription_chunks):
            cursor.execute(
                """
                INSERT INTO videos (type, data, metadata, description)
                VALUES (?, ?, ?, ?)
                """,
                ("text/plain", None, metadata, f"Transcription Chunk {i + 1} for Video {video_id}: {chunk}")
            )

        conn.commit()
        print(f"Saved video and transcription for {video_uri}")
    except Exception as e:
        print(f"Failed to save video or transcription: {e}")


# Transcribe videos and save to database
def transcribe_videos_and_save_to_db(video_uris, max_db_size_mb=100, file_prefix="video_db", db_index = 0,chunk_size=1024):
    vertexai.init(project="gen-lang-client-0676335328", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-002")

    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
    }

    safety_settings = [
        SafetySetting(
            category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
            threshold=SafetySetting.HarmBlockThreshold.OFF,
        ),
        SafetySetting(
            category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
            threshold=SafetySetting.HarmBlockThreshold.OFF,
        ),
        SafetySetting(
            category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
            threshold=SafetySetting.HarmBlockThreshold.OFF,
        ),
        SafetySetting(
            category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
            threshold=SafetySetting.HarmBlockThreshold.OFF,
        ),
    ]
    db_files = []

    db_name = f"{file_prefix}_{db_index}.db"
    conn, cursor = initialize_db(db_name)
    metadata_df = pd.read_csv("/content/missing_metadata.csv",  encoding="latin1")
    for video_uri in video_uris:
        print(f"Processing video: {video_uri}")
        # Create a Part object with the video URI
        video_part = Part.from_uri(mime_type="video/mp4", uri=video_uri)

        # Download video locally
        local_video_path = download_video(video_uri)
        if not local_video_path or not os.path.exists(local_video_path):
            print(f"Failed to download video: {video_uri}")
            continue


        local_file_name = local_video_path.split("/")[-1]

        metadata = find_metadata(metadata_df, local_file_name)
        if metadata is None:
            print(f"No metadata found for {local_file_name}. Skipping video.")
            continue
        print(f"Metadata found: {metadata}")

        # Read video data
        video_data = read_video_file(local_video_path)
        if not video_data:
            os.remove(local_video_path)
            continue

        # Generate transcription

        responses = model.generate_content(
            ["Transcribe the video", video_part],
            generation_config=generation_config,
            safety_settings=safety_settings,
            stream=True,
        )

        transcription = "".join([response.text for response in responses if hasattr(response, "text")])
        transcription_chunks = chunk_data(transcription, chunk_size)

        # Save video data and transcription
        metadata = metadata
        save_video_and_transcription(conn, cursor, video_uri, video_data, metadata, transcription_chunks)

        # Delete local video
        os.remove(local_video_path)
        print(f"Deleted local video: {local_video_path}")

        # Check DB size
        db_size_mb = os.path.getsize(db_name) / (1024 * 1024)
        if db_size_mb >= max_db_size_mb:
            db_files.append(db_name)
            conn.close()
            print(f"Database '{db_name}' reached size limit. Creating a new database.")
            db_index += 1
            db_name = f"{file_prefix}_{db_index}.db"
            conn, cursor = initialize_db(db_name)

    print(db_files)
    conn.close()
      # Add the last DB file
    print(f"All transcriptions saved across {db_index} database file(s).")
    upload_files_to_s3("liveaidb", db_files)


# Helper functions for file handling and chunking
def chunk_data(data, chunk_size):
    words = data.split()
    return [" ".join(words[i:i + chunk_size]) for i in range(0, len(words), chunk_size)]


def read_video_file(file_path):
    try:
        with open(file_path, "rb") as file:
            return file.read()
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None


def download_video(video_uri):
    if video_uri.startswith("gs://"):
        client = storage.Client()
        bucket_name, blob_name = video_uri[5:].split("/", 1)
        bucket = client.bucket(bucket_name)
        blob = bucket.blob(blob_name)
        local_path = os.path.basename(blob_name)
        blob.download_to_filename(local_path)
        print(f"Downloaded video: {video_uri} to {local_path}")
        return local_path
    else:
        print(f"Unsupported URI format: {video_uri}")
        return None
def list_video_files_by_pattern(bucket_name, pattern="temp", file_extension=".mp4"):
    """
    List video files from a Google Cloud Storage bucket matching a pattern.

    Args:
        bucket_name (str): Name of the GCS bucket.
        pattern (str): Pattern to match filenames (e.g., "temp").
        file_extension (str): File extension to filter files (e.g., ".mp4").

    Returns:
        list: List of video file URIs.
    """
    client = storage.Client()
    bucket = client.get_bucket(bucket_name)
    blobs = bucket.list_blobs()
    video_files = [
        f"gs://{bucket_name}/{blob.name}"
        for blob in blobs
        if blob.name.startswith(pattern) and blob.name.endswith(file_extension)
    ]
    return video_files
# Upload database files to S3
def upload_files_to_s3(bucket_name, files):
    """
    Upload multiple files to an S3 bucket.

    Args:
        bucket_name (str): Name of the S3 bucket.
        files (list): List of local file paths to upload.
    """
    s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key,
    region_name=region_name
)
    for file_path in files:
        try:
            s3.upload_file(file_path, bucket_name, os.path.basename(file_path))
            print(f"Uploaded '{file_path}' to S3 bucket '{bucket_name}'.")
            os.remove(file_path)  # Delete the file locally after upload
        except Exception as e:
            print(f"Failed to upload '{file_path}': {e}")

def find_metadata(data, local_file_name):
    """
    Find metadata for a given local file name.

    Args:
        data (DataFrame): The metadata DataFrame.
        local_file_name (str): The local file name to find metadata for.

    Returns:
        str: The metadata associated with the local file name, or None if not found.
    """
    result = data[data['local_file_name'] == local_file_name]
    if not result.empty:
        return result.iloc[0]['metadata']
    else:
        return None


# Main script to dynamically list files and transcribe
bucket_name = "liveai"  # Replace with your GCS bucket name
video_files = list_video_files_by_pattern(bucket_name, pattern="converted_videos/temp", file_extension=".mp4")

if not video_files:
    print("No video files found matching the pattern in the bucket.")
else:
    print(f"Found {len(video_files)} video files. Starting transcription...")
    transcribe_videos_and_save_to_db(video_files,db_index = 7)
# Out:
# Found 89 video files. Starting transcription...
# Processing video: gs://liveai/converted_videos/temp1.mp4
# Downloaded video: gs://liveai/converted_videos/temp1.mp4 to temp1.mp4
# No metadata found for temp1.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp10.mp4
# Downloaded video: gs://liveai/converted_videos/temp10.mp4 to temp10.mp4
# No metadata found for temp10.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp11.mp4
# Downloaded video: gs://liveai/converted_videos/temp11.mp4 to temp11.mp4
# No metadata found for temp11.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp12.mp4
# Downloaded video: gs://liveai/converted_videos/temp12.mp4 to temp12.mp4
# No metadata found for temp12.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp14.mp4
# Downloaded video: gs://liveai/converted_videos/temp14.mp4 to temp14.mp4
# No metadata found for temp14.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp15.mp4
# Downloaded video: gs://liveai/converted_videos/temp15.mp4 to temp15.mp4
# No metadata found for temp15.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp16.mp4
# Downloaded video: gs://liveai/converted_videos/temp16.mp4 to temp16.mp4
# No metadata found for temp16.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp17.mp4
# Downloaded video: gs://liveai/converted_videos/temp17.mp4 to temp17.mp4
# No metadata found for temp17.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp18.mp4
# Downloaded video: gs://liveai/converted_videos/temp18.mp4 to temp18.mp4
# Metadata found: W1D4 - Approaching real world AI problems -2.mov
# Saved video and transcription for gs://liveai/converted_videos/temp18.mp4
# Deleted local video: temp18.mp4
# Processing video: gs://liveai/converted_videos/temp19.mp4
# Downloaded video: gs://liveai/converted_videos/temp19.mp4 to temp19.mp4
# No metadata found for temp19.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp2.mp4
# Downloaded video: gs://liveai/converted_videos/temp2.mp4 to temp2.mp4
# No metadata found for temp2.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp20.mp4
# Downloaded video: gs://liveai/converted_videos/temp20.mp4 to temp20.mp4
# No metadata found for temp20.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp21.mp4
# Downloaded video: gs://liveai/converted_videos/temp21.mp4 to temp21.mp4
# Metadata found: W2D0-Introduction_ML.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp21.mp4
# Deleted local video: temp21.mp4
# Database 'video_db_7.db' reached size limit. Creating a new database.
# Processing video: gs://liveai/converted_videos/temp22.mp4
# Downloaded video: gs://liveai/converted_videos/temp22.mp4 to temp22.mp4
# Metadata found: W2D1 - Introduction to Statistics & Probability-1.mov
# Saved video and transcription for gs://liveai/converted_videos/temp22.mp4
# Deleted local video: temp22.mp4
# Processing video: gs://liveai/converted_videos/temp23.mp4
# Downloaded video: gs://liveai/converted_videos/temp23.mp4 to temp23.mp4
# No metadata found for temp23.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp24.mp4
# Downloaded video: gs://liveai/converted_videos/temp24.mp4 to temp24.mp4
# No metadata found for temp24.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp25.mp4
# Downloaded video: gs://liveai/converted_videos/temp25.mp4 to temp25.mp4
# No metadata found for temp25.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp26.mp4
# Downloaded video: gs://liveai/converted_videos/temp26.mp4 to temp26.mp4
# No metadata found for temp26.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp27.mp4
# Downloaded video: gs://liveai/converted_videos/temp27.mp4 to temp27.mp4
# No metadata found for temp27.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp28.mp4
# Downloaded video: gs://liveai/converted_videos/temp28.mp4 to temp28.mp4
# No metadata found for temp28.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp29.mp4
# Downloaded video: gs://liveai/converted_videos/temp29.mp4 to temp29.mp4
# No metadata found for temp29.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp3.mp4
# Downloaded video: gs://liveai/converted_videos/temp3.mp4 to temp3.mp4
# No metadata found for temp3.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp30.mp4
# Downloaded video: gs://liveai/converted_videos/temp30.mp4 to temp30.mp4
# No metadata found for temp30.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp31.mp4
# Downloaded video: gs://liveai/converted_videos/temp31.mp4 to temp31.mp4
# No metadata found for temp31.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp32.mp4
# Downloaded video: gs://liveai/converted_videos/temp32.mp4 to temp32.mp4
# No metadata found for temp32.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp33.mp4
# Downloaded video: gs://liveai/converted_videos/temp33.mp4 to temp33.mp4
# No metadata found for temp33.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp34.mp4
# Downloaded video: gs://liveai/converted_videos/temp34.mp4 to temp34.mp4
# No metadata found for temp34.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp35.mp4
# Downloaded video: gs://liveai/converted_videos/temp35.mp4 to temp35.mp4
# No metadata found for temp35.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp36.mp4
# Downloaded video: gs://liveai/converted_videos/temp36.mp4 to temp36.mp4
# No metadata found for temp36.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp37.mp4
# Downloaded video: gs://liveai/converted_videos/temp37.mp4 to temp37.mp4
# No metadata found for temp37.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp38.mp4
# Downloaded video: gs://liveai/converted_videos/temp38.mp4 to temp38.mp4
# Metadata found: W2D3 - Getting started with Classification models-SupervisedLearning-1.mov
# Saved video and transcription for gs://liveai/converted_videos/temp38.mp4
# Deleted local video: temp38.mp4
# Processing video: gs://liveai/converted_videos/temp39.mp4
# Downloaded video: gs://liveai/converted_videos/temp39.mp4 to temp39.mp4
# No metadata found for temp39.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp4.mp4
# Downloaded video: gs://liveai/converted_videos/temp4.mp4 to temp4.mp4
# No metadata found for temp4.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp40.mp4
# Downloaded video: gs://liveai/converted_videos/temp40.mp4 to temp40.mp4
# No metadata found for temp40.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp41.mp4
# Downloaded video: gs://liveai/converted_videos/temp41.mp4 to temp41.mp4
# No metadata found for temp41.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp42.mp4
# Downloaded video: gs://liveai/converted_videos/temp42.mp4 to temp42.mp4
# No metadata found for temp42.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp43.mp4
# Downloaded video: gs://liveai/converted_videos/temp43.mp4 to temp43.mp4
# No metadata found for temp43.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp44.mp4
# Downloaded video: gs://liveai/converted_videos/temp44.mp4 to temp44.mp4
# No metadata found for temp44.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp45.mp4
# Downloaded video: gs://liveai/converted_videos/temp45.mp4 to temp45.mp4
# No metadata found for temp45.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp46.mp4
# Downloaded video: gs://liveai/converted_videos/temp46.mp4 to temp46.mp4
# No metadata found for temp46.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp47.mp4
# Downloaded video: gs://liveai/converted_videos/temp47.mp4 to temp47.mp4
# No metadata found for temp47.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp48.mp4
# Downloaded video: gs://liveai/converted_videos/temp48.mp4 to temp48.mp4
# No metadata found for temp48.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp49.mp4
# Downloaded video: gs://liveai/converted_videos/temp49.mp4 to temp49.mp4
# No metadata found for temp49.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp5.mp4
# Downloaded video: gs://liveai/converted_videos/temp5.mp4 to temp5.mp4
# No metadata found for temp5.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp50.mp4
# Downloaded video: gs://liveai/converted_videos/temp50.mp4 to temp50.mp4
# No metadata found for temp50.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp51.mp4
# Downloaded video: gs://liveai/converted_videos/temp51.mp4 to temp51.mp4
# No metadata found for temp51.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp52.mp4
# Downloaded video: gs://liveai/converted_videos/temp52.mp4 to temp52.mp4
# Metadata found: 00-W3_D1__Building_your_first_DL_model____Overview_of_neural_networks.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp52.mp4
# Deleted local video: temp52.mp4
# Database 'video_db_8.db' reached size limit. Creating a new database.
# Processing video: gs://liveai/converted_videos/temp53.mp4
# Downloaded video: gs://liveai/converted_videos/temp53.mp4 to temp53.mp4
# No metadata found for temp53.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp54.mp4
# Downloaded video: gs://liveai/converted_videos/temp54.mp4 to temp54.mp4
# No metadata found for temp54.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp55.mp4
# Downloaded video: gs://liveai/converted_videos/temp55.mp4 to temp55.mp4
# No metadata found for temp55.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp56.mp4
# Downloaded video: gs://liveai/converted_videos/temp56.mp4 to temp56.mp4
# No metadata found for temp56.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp57.mp4
# Downloaded video: gs://liveai/converted_videos/temp57.mp4 to temp57.mp4
# No metadata found for temp57.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp58.mp4
# Downloaded video: gs://liveai/converted_videos/temp58.mp4 to temp58.mp4
# No metadata found for temp58.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp59.mp4
# Downloaded video: gs://liveai/converted_videos/temp59.mp4 to temp59.mp4
# No metadata found for temp59.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp6.mp4
# Downloaded video: gs://liveai/converted_videos/temp6.mp4 to temp6.mp4
# No metadata found for temp6.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp60.mp4
# Downloaded video: gs://liveai/converted_videos/temp60.mp4 to temp60.mp4
# No metadata found for temp60.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp61.mp4
# Downloaded video: gs://liveai/converted_videos/temp61.mp4 to temp61.mp4
# No metadata found for temp61.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp62.mp4
# Downloaded video: gs://liveai/converted_videos/temp62.mp4 to temp62.mp4
# No metadata found for temp62.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp63.mp4
# Downloaded video: gs://liveai/converted_videos/temp63.mp4 to temp63.mp4
# No metadata found for temp63.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp64.mp4
# Downloaded video: gs://liveai/converted_videos/temp64.mp4 to temp64.mp4
# No metadata found for temp64.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp65.mp4
# Downloaded video: gs://liveai/converted_videos/temp65.mp4 to temp65.mp4
# No metadata found for temp65.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp66.mp4
# Downloaded video: gs://liveai/converted_videos/temp66.mp4 to temp66.mp4
# No metadata found for temp66.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp67.mp4
# Downloaded video: gs://liveai/converted_videos/temp67.mp4 to temp67.mp4
# No metadata found for temp67.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp68.mp4
# Downloaded video: gs://liveai/converted_videos/temp68.mp4 to temp68.mp4
# No metadata found for temp68.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp69.mp4
# Downloaded video: gs://liveai/converted_videos/temp69.mp4 to temp69.mp4
# No metadata found for temp69.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp7.mp4
# Downloaded video: gs://liveai/converted_videos/temp7.mp4 to temp7.mp4
# No metadata found for temp7.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp70.mp4
# Downloaded video: gs://liveai/converted_videos/temp70.mp4 to temp70.mp4
# No metadata found for temp70.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp71.mp4
# Downloaded video: gs://liveai/converted_videos/temp71.mp4 to temp71.mp4
# No metadata found for temp71.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp72.mp4
# Downloaded video: gs://liveai/converted_videos/temp72.mp4 to temp72.mp4
# No metadata found for temp72.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp73.mp4
# Downloaded video: gs://liveai/converted_videos/temp73.mp4 to temp73.mp4
# No metadata found for temp73.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp74.mp4
# Downloaded video: gs://liveai/converted_videos/temp74.mp4 to temp74.mp4
# Metadata found: W3D2 - MaxPooling-Softmax.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp74.mp4
# Deleted local video: temp74.mp4
# Processing video: gs://liveai/converted_videos/temp75.mp4
# Downloaded video: gs://liveai/converted_videos/temp75.mp4 to temp75.mp4
# No metadata found for temp75.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp76.mp4
# Downloaded video: gs://liveai/converted_videos/temp76.mp4 to temp76.mp4
# No metadata found for temp76.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp77.mp4
# Downloaded video: gs://liveai/converted_videos/temp77.mp4 to temp77.mp4
# Metadata found: W3D3__CNN_Hands_on_implementation____Image_Processing.mp4
# Downloaded video: gs://liveai/converted_videos/temp78.mp4 to temp78.mp4
# Metadata found: W3D3 - Introduce Transfer Learning - VGG16.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp78.mp4
# Deleted local video: temp78.mp4
# Processing video: gs://liveai/converted_videos/temp79.mp4
# Downloaded video: gs://liveai/converted_videos/temp79.mp4 to temp79.mp4
# Metadata found: W3D3 - Introduce Transfer Learning - Resnet.mov
# Saved video and transcription for gs://liveai/converted_videos/temp79.mp4
# Deleted local video: temp79.mp4
# Processing video: gs://liveai/converted_videos/temp80.mp4
# Downloaded video: gs://liveai/converted_videos/temp80.mp4 to temp80.mp4
# Metadata found: W3D3 (CNN Hands-on implementation) - Image Processing.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp80.mp4
# Deleted local video: temp80.mp4
# Database 'video_db_10.db' reached size limit. Creating a new database.
# Processing video: gs://liveai/converted_videos/temp81.mp4
# Downloaded video: gs://liveai/converted_videos/temp81.mp4 to temp81.mp4
# Metadata found: W3D4__Introduction_to_Language_Model____Overview_of_RNNs-2.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp81.mp4
# Deleted local video: temp81.mp4
# Database 'video_db_11.db' reached size limit. Creating a new database.
# Processing video: gs://liveai/converted_videos/temp83.mp4
# Downloaded video: gs://liveai/converted_videos/temp83.mp4 to temp83.mp4
# Metadata found: W3D4 - Overview of LSTM2.MP4
# Saved video and transcription for gs://liveai/converted_videos/temp83.mp4
# Deleted local video: temp83.mp4
# Processing video: gs://liveai/converted_videos/temp84.mp4
# Downloaded video: gs://liveai/converted_videos/temp84.mp4 to temp84.mp4
# Metadata found: W3D4 - Overview of GRU.MP4
# Saved video and transcription for gs://liveai/converted_videos/temp84.mp4
# Deleted local video: temp84.mp4
# Processing video: gs://liveai/converted_videos/temp85.mp4
# Downloaded video: gs://liveai/converted_videos/temp85.mp4 to temp85.mp4
# Metadata found: W3D4 - Overview of LSTM.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp85.mp4
# Deleted local video: temp85.mp4
# Processing video: gs://liveai/converted_videos/temp86.mp4
# Downloaded video: gs://liveai/converted_videos/temp86.mp4 to temp86.mp4
# Metadata found: W3D4 - Overview of LSTM.mov
# Saved video and transcription for gs://liveai/converted_videos/temp86.mp4
# Deleted local video: temp86.mp4
# Processing video: gs://liveai/converted_videos/temp87.mp4
# Downloaded video: gs://liveai/converted_videos/temp87.mp4 to temp87.mp4
# Metadata found: W3D4 - Sequence Tagger.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp87.mp4
# Deleted local video: temp87.mp4
# Database 'video_db_12.db' reached size limit. Creating a new database.
# Processing video: gs://liveai/converted_videos/temp88.mp4
# Downloaded video: gs://liveai/converted_videos/temp88.mp4 to temp88.mp4
# Metadata found: W3D4 - Implementation of LSTM - (BiLSTM-CRF).mp4
# Saved video and transcription for gs://liveai/converted_videos/temp88.mp4
# Deleted local video: temp88.mp4
# Processing video: gs://liveai/converted_videos/temp89.mp4
# Downloaded video: gs://liveai/converted_videos/temp89.mp4 to temp89.mp4
# No metadata found for temp89.mp4. Skipping video.
# Processing video: gs://liveai/converted_videos/temp9.mp4
# Downloaded video: gs://liveai/converted_videos/temp9.mp4 to temp9.mp4
# Metadata found: W1D1 - Python and libraries-(Dataviz)-5.mov
# Saved video and transcription for gs://liveai/converted_videos/temp9.mp4
# Deleted local video: temp9.mp4
# Processing video: gs://liveai/converted_videos/temp90.mp4
# Downloaded video: gs://liveai/converted_videos/temp90.mp4 to temp90.mp4
# Metadata found: W3D5__Introduction_to_Adv_Language_models__Overview_of_Text_Processing.mp4
# Saved video and transcription for gs://liveai/converted_videos/temp90.mp4
# Deleted local video: temp90.mp4
# Database 'video_db_13.db' reached size limit. Creating a new database.
# Processing video: gs://liveai/converted_videos/temp91.mp4
# Downloaded video: gs://liveai/converted_videos/temp91.mp4 to temp91.mp4
# Metadata found: W3D5 - Overview of Word Embedding.mov
# Saved video and transcription for gs://liveai/converted_videos/temp91.mp4
# Deleted local video: temp91.mp4
# Processing video: gs://liveai/converted_videos/temp92.mp4
# Downloaded video: gs://liveai/converted_videos/temp92.mp4 to temp92.mp4
# Metadata found: W3D5 - Overview of BERT, GPT, CoVE, ULMFiT.mov
# Saved video and transcription for gs://liveai/converted_videos/temp92.mp4
# Deleted local video: temp92.mp4
# ['video_db_7.db', 'video_db_8.db', 'video_db_9.db', 'video_db_10.db', 'video_db_11.db', 'video_db_12.db', 'video_db_13.db']
# All transcriptions saved across 14 database file(s).
# Uploaded 'video_db_7.db' to S3 bucket 'liveaidb'.
# Uploaded 'video_db_8.db' to S3 bucket 'liveaidb'.
# Uploaded 'video_db_9.db' to S3 bucket 'liveaidb'.
# Uploaded 'video_db_10.db' to S3 bucket 'liveaidb'.
# Uploaded 'video_db_11.db' to S3 bucket 'liveaidb'.
# Uploaded 'video_db_12.db' to S3 bucket 'liveaidb'.
# Uploaded 'video_db_13.db' to S3 bucket 'liveaidb'.

# %%
# Restart kernel after installs so that your environment can access the new packages
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
